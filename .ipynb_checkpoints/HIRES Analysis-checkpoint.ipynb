# %%
import numpy as np
from pathlib import Path
from astropy import stats
from astropy import units as u
from astropy.modeling import models, fitting

import warnings
from astropy.utils.exceptions import AstropyDeprecationWarning
warnings.simplefilter('ignore', category=AstropyDeprecationWarning)

from keckdata import KeckData, KeckDataList, fits_reader, analysis

# %%
## HIRES

# p_2019oct11 = Path('/Volumes/JOSHW/HIRES/2019oct11')
# files = sorted([f for f in p_2019oct11.glob('*fits')])
# p_2019oct12 = Path('/Volumes/JOSHW/HIRES/2019oct12')
# files.extend( sorted([f for f in p_2019oct12.glob('*fits')]) )
# kdl_biasesdarks = KeckDataList(files, verbose=False)

# p_2019oct19 = Path('/Volumes/JOSHW/HIRES/2019oct19')
# files = sorted([f for f in p_2019oct19.glob('hires*.fits')])
# kdl_flats = KeckDataList(files, verbose=False)

# RN = analysis.determine_read_noise(kdl_biasesdarks, plot=True, trim=256)
# for i,r in enumerate(RN):
#     print(f"Read Noise (ext {i}) = {r:.2f}")

# master_bias = analysis.make_master_bias(kdl_biasesdarks)
# DC = analysis.determine_dark_current(kdl_biasesdarks, master_bias=master_bias, plot=True, trim=256, nozero=True)
# for i,d in enumerate(DC):
#     print(f"Dark Current (ext {i}) = {d:.4f}")
# del(kdl_biasesdarks)

# g = analysis.determine_gain(kdl_flats, master_bias=master_bias, read_noise=RN, trim=256, aduthreshold=25000, plot=True)
# for i,gi in enumerate(g):
#     print(f"Gain (ext {i}) = {gi:.2f}")

# for i,r in enumerate(RN):
#     print(f"Read Noise (ext {i}) = {r*g[i]:.2f}")
# for i,d in enumerate(DC):
#     print(f"Dark Current (ext {i}) = {d*g[i]:.4f}")

# del(kdl_flats)

# %%
p_2019nov06 = Path('/Volumes/JOSHW/HIRES/2019nov06')
files = sorted([f for f in p_2019nov06.glob('hires*.fits')])
kdl = KeckDataList(files, verbose=False)
print(kdl.len)
# Out:
# 153

# %%
RN = analysis.determine_read_noise(kdl, plot=True, trim=256)
for i,r in enumerate(RN):
    print(f"Read Noise (ext {i}) = {r:.2f}")
# Out:
# 2019-11-06 11:54:06     INFO: Determining read noise
# 2019-11-06 11:54:06     INFO:   Checking that all inputs are BIAS frames
# 2019-11-06 11:54:06     INFO:   Found 38 biases
# 2019-11-06 11:54:06     INFO: Making master bias from 37 frames
# 2019-11-06 11:54:06     INFO: Making master bias for each of 3 extensions
# 2019-11-06 11:55:09     INFO:   Done
# 2019-11-06 11:55:10     INFO:   Determining read noise for each of 3 extensions
# 2019-11-06 11:55:11     INFO:   Read Noise is 1.35 adu for extension 1
# 2019-11-06 11:55:11     INFO:   Generating plot for: hires0148.fits, frame 0
# 2019-11-06 11:55:12     INFO:   Generating read noise plot: read_noise_HIRES_ext0.png
# 2019-11-06 11:55:15     INFO:   Read Noise is 1.28 adu for extension 2
# 2019-11-06 11:55:15     INFO:   Generating plot for: hires0148.fits, frame 1
# 2019-11-06 11:55:16     INFO:   Generating read noise plot: read_noise_HIRES_ext1.png
# 2019-11-06 11:55:19     INFO:   Read Noise is 1.31 adu for extension 3
# 2019-11-06 11:55:19     INFO:   Generating plot for: hires0148.fits, frame 2
# 2019-11-06 11:55:20     INFO:   Generating read noise plot: read_noise_HIRES_ext2.png
# Read Noise (ext 0) = 1.35 adu
# Read Noise (ext 1) = 1.28 adu
# Read Noise (ext 2) = 1.31 adu

# %%
master_bias = analysis.make_master_bias(kdl)
DC = analysis.determine_dark_current(kdl, master_bias=master_bias, plot=True, trim=256, nozero=True)
for i,d in enumerate(DC):
    print(f"Dark Current (ext {i}) = {d:.4f}")
# Out:
# 2019-11-06 11:55:24     INFO: Making master bias from 38 frames
# 2019-11-06 11:55:24     INFO: Making master bias for each of 3 extensions
# 2019-11-06 11:56:29     INFO:   Done
# 2019-11-06 11:56:29     INFO: Determining dark current
# 2019-11-06 11:56:29     INFO:   Found 25 dark frames
# 2019-11-06 11:56:29     INFO:   Determining dark current for each of 3 extensions
# 2019-11-06 11:56:54     INFO:   Obtained statistics for frames with 21 different exposure times
# 2019-11-06 11:56:54     INFO:   Determining dark current from
# 2019-11-06 11:56:54     INFO:     5 60 second darks
# 2019-11-06 11:56:54     INFO:     5 120 second darks
# 2019-11-06 11:56:54     INFO:     5 300 second darks
# 2019-11-06 11:56:54     INFO:     5 600 second darks
# 2019-11-06 11:56:54     INFO:     5 900 second darks
# 2019-11-06 11:56:54     INFO:   Dark Current is 0.000 adu / s for extension 1
# 2019-11-06 11:56:54     INFO:   Generating plot for dark current for frame 0
# 2019-11-06 11:56:54     INFO:   Generating dark current plot: dark_current_HIRES_ext0.png
# 2019-11-06 11:56:54     INFO:   Dark Current is 0.001 adu / s for extension 2
# 2019-11-06 11:56:54     INFO:   Generating plot for dark current for frame 1
# 2019-11-06 11:56:54     INFO:   Generating dark current plot: dark_current_HIRES_ext1.png
# 2019-11-06 11:56:55     INFO:   Dark Current is 0.000 adu / s for extension 3
# 2019-11-06 11:56:55     INFO:   Generating plot for dark current for frame 2
# 2019-11-06 11:56:55     INFO:   Generating dark current plot: dark_current_HIRES_ext2.png
# Dark Current (ext 0) = 0.0003 adu / s
# Dark Current (ext 1) = 0.0008 adu / s
# Dark Current (ext 2) = 0.0003 adu / s

# %%
g = analysis.determine_gain(kdl, master_bias=master_bias, read_noise=RN, trim=256, aduthreshold=25000, plot=True)
for i,gi in enumerate(g):
    print(f"Gain (ext {i}) = {gi:.2f}")

for i,r in enumerate(RN):
    print(f"Read Noise (ext {i}) = {r*g[i]:.2f}")
for i,d in enumerate(DC):
    print(f"Dark Current (ext {i}) = {d*g[i]:.4f}")
# Out:
# 2019-11-06 11:56:55     INFO: Determining gain
# 2019-11-06 11:56:55     INFO: Step 1: Get image statistics for 90 flat frames
# 2019-11-06 11:56:55     INFO: Each frame has 3 extensions
# 2019-11-06 11:59:11     INFO: Step 2: Analyze image differences at each of 18 exposure times
# 2019-11-06 11:59:11     INFO:   Measuring statistics for 5 5s flats
# 2019-11-06 11:59:18     INFO:   Measuring statistics for 5 10s flats
# 2019-11-06 11:59:23     INFO:   Measuring statistics for 5 15s flats
# 2019-11-06 11:59:27     INFO:   Measuring statistics for 5 20s flats
# 2019-11-06 11:59:29     INFO:   Measuring statistics for 5 25s flats
# 2019-11-06 11:59:32     INFO:   Measuring statistics for 5 30s flats
# 2019-11-06 11:59:34     INFO:   Measuring statistics for 5 35s flats
# 2019-11-06 11:59:37     INFO:   Measuring statistics for 5 40s flats
# 2019-11-06 11:59:39     INFO:   Measuring statistics for 5 45s flats
# 2019-11-06 11:59:41     INFO:   Measuring statistics for 5 50s flats
# 2019-11-06 11:59:44     INFO:   Measuring statistics for 5 55s flats
# 2019-11-06 11:59:56     INFO:   Measuring statistics for 5 60s flats
# 2019-11-06 12:00:00     INFO:   Measuring statistics for 5 80s flats
# 2019-11-06 12:00:03     INFO:   Measuring statistics for 5 100s flats
# 2019-11-06 12:00:06     INFO:   Measuring statistics for 5 140s flats
# 2019-11-06 12:00:09     INFO:   Measuring statistics for 5 180s flats
# 2019-11-06 12:00:12     INFO:   Measuring statistics for 5 240s flats
# 2019-11-06 12:00:14     INFO:   Measuring statistics for 5 300s flats
# 2019-11-06 12:00:17     INFO: Step 3: Fit gain and linearity for each extension
# 2019-11-06 12:00:17     INFO: Fitting model to determine gain for extension 0
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# 2019-11-06 12:00:17     INFO:   Gain = 2.015 electron / adu
# 2019-11-06 12:00:17     INFO:   Generating figures with flat statistics and gain fits
# 2019-11-06 12:00:18     INFO:   Generating figure with linearity plot
# 2019-11-06 12:00:18     INFO: Fitting model to determine gain for extension 1
# 2019-11-06 12:00:18     INFO:   Gain = 2.080 electron / adu
# 2019-11-06 12:00:18     INFO:   Generating figures with flat statistics and gain fits
# 2019-11-06 12:00:19     INFO:   Generating figure with linearity plot
# 2019-11-06 12:00:20     INFO: Fitting model to determine gain for extension 2
# 2019-11-06 12:00:20     INFO:   Gain = 2.091 electron / adu
# 2019-11-06 12:00:20     INFO:   Generating figures with flat statistics and gain fits
# 2019-11-06 12:00:20     INFO:   Generating figure with linearity plot
# Gain (ext 0) = 2.02 electron / adu
# Gain (ext 1) = 2.08 electron / adu
# Gain (ext 2) = 2.09 electron / adu
# Read Noise (ext 0) = 2.71 electron
# Read Noise (ext 1) = 2.67 electron
# Read Noise (ext 2) = 2.75 electron
# Dark Current (ext 0) = 0.0007 electron / s
# Dark Current (ext 1) = 0.0016 electron / s
# Dark Current (ext 2) = 0.0005 electron / s
